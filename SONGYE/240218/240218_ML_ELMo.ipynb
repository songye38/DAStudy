# %%
import tensorflow_hub as hub
import tensorflow as tf

# ELMo 모델 로드
elmo = hub.load("https://tfhub.dev/google/elmo/3")

# 입력 문장
input_text = ["Hello, how are you?", "What is the weather today?"]

# 문장을 ELMo 임베딩으로 변환
embeddings = elmo(input_text, signature="default", as_dict=True)["elmo"]

# TensorFlow 세션 시작
with tf.compat.v1.Session() as sess:
    # 임베딩 계산
    sess.run(tf.compat.v1.global_variables_initializer())
    sess.run(tf.compat.v1.tables_initializer())
    embedded_sequences = sess.run(embeddings)

# 임베딩 결과 출력
print(embedded_sequences.shape)  # (2, max_length, embedding_dim)
# Out:
# 2024-02-16 16:30:19.390054: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import tensorflow as tf
#       4 # ELMo 모델 로드
# ----> 5 elmo = hub.load("https://tfhub.dev/google/elmo/3")
#       7 # 입력 문장
#       8 input_text = ["Hello, how are you?", "What is the weather today?"]
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/module_v2.py:100, in load(handle, tags, options)
#      98 if not isinstance(handle, str):
#      99   raise ValueError("Expected a string, got %s" % handle)
# --> 100 module_path = resolve(handle)
#     101 is_hub_module_v1 = tf.io.gfile.exists(_get_module_proto_path(module_path))
#     102 if tags is None and is_hub_module_v1:
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/module_v2.py:55, in resolve(handle)
#      31 def resolve(handle):
#      32   """Resolves a module handle into a path.
#      33
#      34   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      53     A string representing the Module path.
#      54   """
# ---> 55   return registry.resolver(handle)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/registry.py:49, in MultiImplRegister.__call__(self, *args, **kwargs)
#      47 for impl in reversed(self._impls):
#      48   if impl.is_supported(*args, **kwargs):
# ---> 49     return impl(*args, **kwargs)
#      50   else:
#      51     fails.append(type(impl).__name__)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/compressed_module_resolver.py:81, in HttpCompressedFileResolver.__call__(self, handle)
#      77   response = self._call_urlopen(request)
#      78   return resolver.DownloadManager(handle).download_and_uncompress(
#      79       response, tmp_dir)
# ---> 81 return resolver.atomic_download(handle, download, module_dir,
#      82                                 self._lock_file_timeout_sec())
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/resolver.py:421, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     419 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     420 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 421 download_fn(handle, tmp_dir)
#     422 # Write module descriptor to capture information about which module was
#     423 # downloaded by whom and when. The file stored at the same level as a
#     424 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     429 # module caching protocol and no code in the TF-Hub library reads its
#     430 # content.
#     431 _write_module_descriptor_file(handle, module_dir)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/compressed_module_resolver.py:78, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      75 request = urllib.request.Request(
#      76     self._append_compressed_format_query(handle))
#      77 response = self._call_urlopen(request)
# ---> 78 return resolver.DownloadManager(handle).download_and_uncompress(
#      79     response, tmp_dir)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/resolver.py:192, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     182 """Streams the content for the 'fileobj' and stores the result in dst_path.
#     183
#     184 Args:
#    (...)
#     189   ValueError: Unknown object encountered inside the TAR file.
#     190 """
#     191 try:
# --> 192   file_utils.extract_tarfile_to_destination(
#     193       fileobj, dst_path, log_function=self._log_progress)
#     194   total_size_str = tf_utils.bytes_to_readable_str(
#     195       self._total_bytes_downloaded, True)
#     196   self._print_download_progress_msg(
#     197       "Downloaded %s, Total size: %s" % (self._url, total_size_str),
#     198       flush=True)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/file_utils.py:52, in extract_tarfile_to_destination(fileobj, dst_path, log_function)
#      49 abs_target_path = merge_relative_path(dst_path, tarinfo.name)
#      51 if tarinfo.isfile():
# ---> 52   extract_file(tgz, tarinfo, abs_target_path, log_function=log_function)
#      53 elif tarinfo.isdir():
#      54   tf.compat.v1.gfile.MakeDirs(abs_target_path)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/site-packages/tensorflow_hub/file_utils.py:35, in extract_file(tgz, tarinfo, dst_path, buffer_size, log_function)
#      33 dst = tf.compat.v1.gfile.GFile(dst_path, "wb")
#      34 while 1:
# ---> 35   buf = src.read(buffer_size)
#      36   if not buf:
#      37     break
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/tarfile.py:700, in _FileInFile.readinto(self, b)
#     699 def readinto(self, b):
# --> 700     buf = self.read(len(b))
#     701     b[:len(buf)] = buf
#     702     return len(buf)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/tarfile.py:689, in _FileInFile.read(self, size)
#     687 if data:
#     688     self.fileobj.seek(offset + (self.position - start))
# --> 689     b = self.fileobj.read(length)
#     690     if len(b) != length:
#     691         raise ReadError("unexpected end of data")
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/tarfile.py:526, in _Stream.read(self, size)
#     524 """Return the next size number of bytes from the stream."""
#     525 assert size is not None
# --> 526 buf = self._read(size)
#     527 self.pos += len(buf)
#     528 return buf
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/tarfile.py:544, in _Stream._read(self, size)
#     542     self.buf = b""
#     543 else:
# --> 544     buf = self.fileobj.read(self.bufsize)
#     545     if not buf:
#     546         break
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/aiffel2/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
